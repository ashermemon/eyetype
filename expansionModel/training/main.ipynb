# %%
# %pip install -r expansionModel/training/requirements.txt
# Out:
# /content
# sample_data
# CWD: /content
# Files: ['.config', 'sample_data']
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'expansionModel/training/requirements.txt'

# %%
# !python finetune_model.py
# Out:
# python3: can't open file '/content/finetune_model.py': [Errno 2] No such file or directory
